# %% [markdown]
# # 🚀 Construction Pipeline - Test Suite Principal
#
# Ce notebook exécute tous les tests de validation du pipeline de construction.
#
# **Organisation:**
# - ✅ **PTF_MVT**: Tests du module Portfolio Movements (AZ + AZEC)
# - ✅ **Capitaux**: Tests d'extraction des capitaux (SMP/LCI)
# - ✅ **Emissions**: Tests des primes émises (One BI)
# - ✅ **Utils**: Tests des utilitaires et transformations
#
# **Utilisation:**
# 1. Exécuter tous les tests: `Run All`
# 2. Tests individuels: Décommenter les sections souhaitées
#
# ---

# %% [markdown]
# ## 📋 Configuration Initiale

# %%
import sys
from pathlib import Path

# Configuration du projet
project_root = Path.cwd().parent
sys.path.insert(0, str(project_root))

print("" + "="*70)
print(" CONSTRUCTION PIPELINE - SUITE DE TESTS COMPLÈTE")
print("="*70)
print(f" 📁 Project Root: {project_root}")
print(f" 📘 Notebooks: {Path.cwd()}")
print("="*70 + "\n")

# %% [markdown]
# ---
# ## 🔍 0. Découverte des Colonnes
#
# Tests de découverte et validation des schémas de données.

# %%
print("\n" + "="*70)
print(" 🔍 DÉCOUVERTE DES COLONNES")
print("="*70 + "\n")

# %run 00_column_discovery.ipynb

# %% [markdown]
# ---
# ## 🔧 4. Tests UTILS
#
# Tests des utilitaires, helpers, et transformations génériques.

# %%
print("\n" + "="*70)
print(" 🔧 UTILS - TESTS")
print("="*70 + "\n")

# 4.1 Helpers
print("\n➤ 4.1 Helpers Testing...")
# %run utils/01_helpers_testing.ipynb

# 4.2 Generic Transforms
print("\n➤ 4.2 Generic Transforms & Business Logic...")
# %run utils/02_generic_transforms_business_logic_testing.ipynb

# 4.3 Capital/AZEC/Emissions Testing
print("\n➤ 4.3 Capital, AZEC & Emissions Transforms...")
# %run utils/03_capital_azec_emissions_testing.ipynb

print("\n✅ UTILS Tests terminés!")

# %% [markdown]
# ---
# ## 📊 1. Tests PTF_MVT (Portfolio Movements)
#
# Tests complets du module PTF_MVT: lecture bronze, filtres, processeurs AZ/AZEC, consolidation.

# %%
print("\n" + "="*70)
print(" 📊 PTF_MVT - TESTS")
print("="*70 + "\n")

# 1.1 Bronze Reading & Filters
print("\n➤ 1.1 Bronze Reading & Filters...")
# %run ptf_mvt/01_bronze_reading_filters.ipynb

# 1.2 AZ Processor
print("\n➤ 1.2 AZ Processor Testing...")
# %run ptf_mvt/02_az_processor_testing.ipynb

# 1.3 AZEC Processor
print("\n➤ 1.3 AZEC Processor Testing...")
# %run ptf_mvt/03_azec_processor_testing.ipynb

# 1.4 Consolidation
print("\n➤ 1.4 Consolidation Testing...")
# %run ptf_mvt/04_consolidation_testing.ipynb

print("\n✅ PTF_MVT Tests terminés!")

# %% [markdown]
# ---
# ## 💰 2. Tests CAPITAUX
#
# Tests d'extraction et normalisation des capitaux (SMP/LCI) pour AZ et AZEC.

# %%
print("\n" + "="*70)
print(" 💰 CAPITAUX - TESTS")
print("="*70 + "\n")

# 2.1 AZ Capitaux
print("\n➤ 2.1 AZ Capitaux Testing...")
# %run capitaux/01_az_capitaux_testing.ipynb

# 2.2 AZEC Capitaux
print("\n➤ 2.2 AZEC Capitaux Testing...")
# %run capitaux/02_azec_capitaux_testing.ipynb

# 2.3 Pipeline Complet
print("\n➤ 2.3 Full Capitaux Pipeline...")
# %run capitaux/03_full_pipeline_testing.ipynb

print("\n✅ CAPITAUX Tests terminés!")

# %% [markdown]
# ---
# ## 📈 3. Tests EMISSIONS
#
# Tests du module Emissions (One BI premium data processing).

# %%
print("\n" + "="*70)
print(" 📈 EMISSIONS - TESTS")
print("="*70 + "\n")

# 3.1 Bronze Filters
print("\n➤ 3.1 Bronze Filters Testing...")
# %run emissions/01_bronze_filters_testing.ipynb

# 3.2 Pipeline Complet
print("\n➤ 3.2 Full Emissions Pipeline...")
# %run emissions/02_full_pipeline_testing.ipynb

print("\n✅ EMISSIONS Tests terminés!")

# %% [markdown]
# ---
# ## ✅ Résumé Final

# %%
print("\n" + "="*70)
print(" ✅ TOUS LES TESTS TERMINÉS AVEC SUCCÈS!")
print("="*70)
print()
print(" 📊 Composants testés:")
print("    ✓ PTF_MVT (4 notebooks)")
print("    ✓ Capitaux (3 notebooks)")
print("    ✓ Emissions (2 notebooks)")
print("    ✓ Utils (3 notebooks)")
print("    ✓ Column Discovery (1 notebook)")
print()
print(" 📈 Total: 13 notebooks de tests exécutés")
print()
print("="*70)
print(" 🎉 Pipeline de Construction - Tests validés!")
print("="*70)
