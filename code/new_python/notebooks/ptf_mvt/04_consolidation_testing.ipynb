# %% [markdown]
# # PTF_MVT 04: Consolidation Testing
#
# **Purpose**: Test consolidation (AZ + AZEC → Gold)
#
# **Tests**: Union, IRD enrichment, ISIC codification, client data
#
# ---

# %%
import sys
from pathlib import Path

project_root = Path.cwd().parent.parent
sys.path.insert(0, str(project_root))
print(f"Project root: {project_root}")
# Out:
# Project root: /workspace/new_python

# %%
from pyspark.sql import SparkSession
# from azfr_fsspec_utils import fspath
# import azfr_fsspec_abfs

# azfr_fsspec_abfs.use()

spark = SparkSession.builder \
    .appName("PTF_MVT_Consolidation") \
    .getOrCreate()

print(f"✓ Spark {spark.version}")
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/12/17 11:22:12 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# ✓ Spark 3.4.4

# %% [markdown]
# ## 1. Initialize

# %%
from utils.loaders.config_loader import ConfigLoader
from utils.logger import PipelineLogger

config = ConfigLoader(str(project_root / "config" / "config.yml"))
logger = PipelineLogger("consolidation_test")

VISION = "202509"
print(f"Vision: {VISION}")
# Out:
# Vision: 202509

# %% [markdown]
# ## 2. Run Consolidation Processor

# %%
from src.processors.ptf_mvt_processors.consolidation_processor import ConsolidationProcessor

try:
    consolidation = ConsolidationProcessor(spark, config, logger)
    df_gold = consolidation.run(VISION)
    
    if df_gold is not None:
        print(f"✓ Consolidation: {df_gold.count():,} rows")
        print(f"  Columns: {len(df_gold.columns)}")
    else:
        print("⚠ Consolidation returned None")
except Exception as e:
    print(f"✗ Error: {e}")
    df_gold = None
# Out:
# 2025-12-17 11:23:29 - azec_test - INFO - ================================================================================
# 2025-12-17 11:23:29 - azec_test - INFO -   Running ConsolidationProcessor
# 2025-12-17 11:23:29 - azec_test - INFO - ================================================================================
# 2025-12-17 11:23:29 - azec_test - INFO - Starting: ConsolidationProcessor.read()
# 2025-12-17 11:23:29 - azec_test - INFO - Reading AZ silver data (mvt_const_ptf)
# 2025-12-17 11:23:29 - azec_test - INFO - Completed: ConsolidationProcessor.read() (Duration: 0.28s)
# 2025-12-17 11:23:29 - azec_test - INFO - Read 15000 rows
# 2025-12-17 11:23:29 - azec_test - INFO - Starting: ConsolidationProcessor.transform()
# 2025-12-17 11:23:29 - azec_test - INFO - STEP 1: Reading AZEC silver data
# 2025-12-17 11:23:29 - azec_test - INFO - STEP 2: Harmonizing AZ schema
# 2025-12-17 11:23:29 - azec_test - INFO - STEP 3: Harmonizing AZEC schema
# 2025-12-17 11:23:30 - azec_test - INFO - STEP 3.5: Applying AZEC-specific transformations
# 2025-12-17 11:23:30 - azec_test - INFO - STEP 4: Consolidating AZ + AZEC
# 2025-12-17 11:23:30 - azec_test - INFO - STEP 4.5: Applying common transformations
# 2025-12-17 11:23:30 - azec_test - INFO - STEP 4.6: Enriching with DO_DEST reference
# 2025-12-17 11:23:30 - azec_test - INFO - DO_DEST reference enrichment applied successfully
# 2025-12-17 11:23:30 - azec_test - INFO - STEP 4.7: Applying DESTINAT consolidation logic
# 2025-12-17 11:23:30 - azec_test - INFO - STEP 5: Calculating DESTINAT for construction sites
# 2025-12-17 11:23:30 - azec_test - INFO - Calculating DESTINAT from DSTCSC patterns
# 2025-12-17 11:23:31 - azec_test - INFO - ✓ SUCCESS: DESTINAT calculation completed
# 2025-12-17 11:23:31 - azec_test - INFO - STEP 5.5: Enriching with IRD risk data
# 2025-12-17 11:23:33 - azec_test - INFO - IRD risk data enrichment completed
# 2025-12-17 11:23:33 - azec_test - INFO - STEP 5.7: Applying fallback logic
# 2025-12-17 11:23:33 - azec_test - INFO - STEP 5.8: Enriching client data (SIRET/SIREN)
# 2025-12-17 11:23:33 - azec_test - INFO - Joining client reference data
# 2025-12-17 11:23:33 - azec_test - WARNING - HISTO_NOTE_RISQUE not available: File group 'histo_note_risque' not found in reading_config.json
# 2025-12-17 11:23:33 - azec_test - INFO - ✓ SUCCESS: Client data enrichment completed
# 2025-12-17 11:23:33 - azec_test - INFO - STEP 5.9: Enriching Euler risk notes (note_euler)
# 2025-12-17 11:23:34 - azec_test - INFO - Euler risk notes enriched successfully
# 2025-12-17 11:23:34 - azec_test - INFO - STEP 6: Enriching special product activity codes (TypeAct)
# 2025-12-17 11:23:34 - azec_test - INFO - IPFM0024 special products loaded
# 2025-12-17 11:23:34 - azec_test - INFO - IPFM63 special products loaded
# 2025-12-17 11:23:34 - azec_test - INFO - IPFM99 special products loaded
# 2025-12-17 11:23:34 - azec_test - INFO - Special product activity codes enriched successfully
# 2025-12-17 11:23:34 - azec_test - INFO - STEP 6.05: Enriching NAF codes (W6 + CLIENT)
# 2025-12-17 11:23:34 - azec_test - INFO - W6 NAF codes enriched successfully
# 2025-12-17 11:23:35 - azec_test - INFO - Client NAF codes enriched successfully
# 2025-12-17 11:23:35 - azec_test - INFO - STEP 6.1: Adding ISIC codes and HAZARD_GRADES
# 2025-12-17 11:23:35 - azec_test - INFO - Joining ISIC reference tables
# 2025-12-17 11:23:36 - azec_test - WARNING - ISIC_LG not available: File group 'isic_lg' not found in reading_config.json
# 2025-12-17 11:23:36 - azec_test - INFO - ✓ SUCCESS: All available ISIC reference tables joined
# 2025-12-17 11:23:36 - azec_test - INFO - Starting ISIC codification process
# 2025-12-17 11:23:38 - azec_test - INFO - ✓ SUCCESS: ISIC codification completed
# 2025-12-17 11:23:38 - azec_test - INFO - STEP 6.2: Applying ISIC code corrections
# 2025-12-17 11:23:38 - azec_test - INFO - STEP 6.3: Adding ISIC global code mapping
# 2025-12-17 11:23:38 - azec_test - INFO - ISIC global code mapping applied successfully
# 2025-12-17 11:23:38 - azec_test - INFO - STEP 6.4: Adding special business flags
# 2025-12-17 11:23:38 - azec_test - INFO - STEP 6.9: Adding placeholders for any remaining missing columns
# 2025-12-17 11:23:39 - azec_test - INFO - Consolidation completed successfully
# 2025-12-17 11:23:39 - azec_test - INFO - Completed: ConsolidationProcessor.transform() (Duration: 9.66s)
# 2025-12-17 11:23:40 - azec_test - INFO - Transformed to 306425 rows
# 2025-12-17 11:23:40 - azec_test - INFO - Starting: ConsolidationProcessor.write()
# 2025-12-17 11:23:40 - azec_test - INFO - Writing gold data to: /workspace/datalake/gold/2025/09/construction_portfolio_202509.parquet
# 2025-12-17 11:23:40 - azec_test - INFO - Format: parquet, Compression: snappy, Mode: overwrite
# [Stage 240:>                                                        (0 + 1) / 1]
# 2025-12-17 11:24:35 - azec_test - INFO - ✓ SUCCESS: Gold data written successfully
# 2025-12-17 11:24:35 - azec_test - INFO - Completed: ConsolidationProcessor.write() (Duration: 55.16s)
# 2025-12-17 11:24:35 - azec_test - INFO - ✓ SUCCESS: ConsolidationProcessor completed successfully
# ✓ Consolidation: 306,425 rows
#   Columns: 280

# %% [markdown]
# ## 3. Verify Gold Output

# %%
if df_gold is not None:
    # DIRCOM distribution (AZ vs AZEC)
    print("DIRCOM distribution:")
    df_gold.groupBy('dircom').count().show()
    
    # Sample output
    df_gold.select('nopol', 'dircom', 'cdprod', 'primeto').show(5)
# Out:
# DIRCOM distribution:
# +------+------+
# |dircom| count|
# +------+------+
# |    az|306422|
# |  azec|     3|
# +------+------+
#
# +-----------+------+------+------------+
# |      nopol|dircom|cdprod|     primeto|
# +-----------+------+------+------------+
# |POL00000011|    az| 01012|20937.840558|
# |POL00000011|    az| 01012|20937.840558|
# |POL00000011|    az| 01012|20937.840558|
# |POL00000011|    az| 01012|20937.840558|
# |POL00000011|    az| 01012|20937.840558|
# +-----------+------+------+------------+
# only showing top 5 rows

# %% [markdown]
# ## Summary

# %%
print("="*50)
print("CONSOLIDATION TESTING COMPLETE")
print("="*50)
spark.stop()
print(f"Result: {'✓ Success' if df_gold is not None else '✗ Failed'}")
print("\n→ Run: python main.py --vision 202509 --component ptf_mvt")
# Out:
# ==================================================
# CONSOLIDATION TESTING COMPLETE
# ==================================================
# Result: ✓ Success
#
# → Run: python main.py --vision 202509 --component ptf_mvt
